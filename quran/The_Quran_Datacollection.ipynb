# %%
import pandas as pd
import psycopg2
from datasets import load_dataset
from typing import Dict, List
from collections import defaultdict

# %%
import os
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
def create_db_connection(db_host: str, db_name: str, db_user: str, db_password: str, db_port: str = "5432"):
    """Create and return database connection and cursor"""
    conn = psycopg2.connect(
        host=db_host,
        database=db_name,
        user=db_user,
        password=db_password,
        port=db_port
    )
    return conn, conn.cursor()

# %%
def insert_surahs(cursor, df: pd.DataFrame) -> Dict[int, int]:
    """Insert unique surahs and return a mapping of surah numbers to their IDs"""
    surahs_data = df[['surah', 'surah_name', 'surah_name_transliteration', 'surah_name_en',
                      'surah_total_ayas', 'surah_type', 'surah_order_revealed', 'surah_rukus']].drop_duplicates()

    surah_mapping = {}
    for _, row in surahs_data.iterrows():
        cursor.execute("""
            INSERT INTO surahs (
                surah_id, name, name_transliteration, name_en, 
                total_ayas, type, order_revealed, rukus
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            RETURNING surah_id;
        """, (
            row['surah'], row['surah_name'], row['surah_name_transliteration'],
            row['surah_name_en'], row['surah_total_ayas'], row['surah_type'],
            row['surah_order_revealed'], row['surah_rukus']
        ))
        surah_mapping[row['surah']] = cursor.fetchone()[0]

    return surah_mapping

# %%
def insert_languages_and_translators(cursor, df: pd.DataFrame) -> Dict[str, int]:
    """
    Insert languages and translators, return translator mapping.
    Only processes language codes that are exactly 2 characters long.
    """
    # Extract translator columns
    translation_cols = [
        col for col in df.columns if col.startswith('translation_')]

    # Create language entries
    languages = set()
    translator_to_lang = {}

    for col in translation_cols:
        # Extract language code (characters after 'translation_')
        parts = col.split('_')
        if len(parts) >= 3:
            lang_code = parts[1]

            # Only process if language code is exactly 2 characters
            if len(lang_code) == 2:
                languages.add(lang_code)
                # Join the remaining parts to get the translator name
                translator = '_'.join(parts[2:])
                translator_to_lang[translator] = lang_code
            else:
                print(
                    f"Skipping invalid language code: {lang_code} from column: {col}")

    # Insert valid languages
    for lang_code in languages:
        cursor.execute("""
            INSERT INTO languages (language_code, language_name)
            VALUES (%s, %s)
            ON CONFLICT (language_code) DO NOTHING;
        """, (lang_code, lang_code.upper()))

    # Insert translators and get mapping
    translator_mapping = {}
    for translator, lang_code in translator_to_lang.items():
        cursor.execute("""
            INSERT INTO translators (name, language_code)
            VALUES (%s, %s)
            RETURNING translator_id;
        """, (translator, lang_code))
        translator_mapping[translator] = cursor.fetchone()[0]

    # Print summary of processing
    print(f"Processed {len(languages)} valid languages")
    print(f"Processed {len(translator_mapping)} translators")

    return translator_mapping

# %%
def insert_ayahs(cursor, df: pd.DataFrame, surah_mapping: Dict[int, int]) -> Dict[tuple, int]:
    """Insert ayahs and return mapping of (surah, ayah) to ayah_id"""
    ayah_mapping = {}

    for _, row in df.iterrows():
        cursor.execute("""
            INSERT INTO ayahs (
                surah_id, ayah_number,
                arabic_text_simple, arabic_text_simple_min,
                arabic_text_simple_plain, arabic_text_simple_clean,
                arabic_text_uthmani, arabic_text_original
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            RETURNING ayah_id;
        """, (
            surah_mapping[row['surah']], row['ayah'],
            row['arabic_text_simple'], row['arabic_text_simple_min'],
            row['arabic_text_simple_plain'], row['arabic_text_simple_clean'],
            row['arabic_text_uthmani'], row['arabic_text_original']
        ))
        ayah_mapping[(row['surah'], row['ayah'])] = cursor.fetchone()[0]

    return ayah_mapping

# %%
def insert_translations(cursor, df: pd.DataFrame, ayah_mapping: Dict[tuple, int], translator_mapping: Dict[str, int]):
    """Insert translations"""
    translation_cols = [
        col for col in df.columns if col.startswith('translation_')]

    for _, row in df.iterrows():
        ayah_id = ayah_mapping[(row['surah'], row['ayah'])]

        for col in translation_cols:
            translator = col.split('_', 2)[2]
            translator_id = translator_mapping[translator]

            if pd.notna(row[col]):  # Only insert if translation exists
                cursor.execute("""
                    INSERT INTO translations (ayah_id, translator_id, translation_text)
                    VALUES (%s, %s, %s)
                    ON CONFLICT (ayah_id, translator_id) DO UPDATE 
                    SET translation_text = EXCLUDED.translation_text;
                """, (ayah_id, translator_id, row[col]))

# %%
# Load the dataset
dataset = load_dataset("nazimali/quran")
df = dataset["train"].to_pandas()
df.columns = df.columns.str.replace('-', '_')
# Out:
# Resolving data files:   0%|          | 0/172 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/172 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#    surah  ayah surah_name  surah_total_ayas surah_name_transliteration  \
# 0      1     1    الفاتحة                 7                 Al-Faatiha
# 1      1     2    الفاتحة                 7                 Al-Faatiha
# 2      1     3    الفاتحة                 7                 Al-Faatiha
# 3      1     4    الفاتحة                 7                 Al-Faatiha
# 4      1     5    الفاتحة                 7                 Al-Faatiha
#
#   surah_name_en surah_type  surah_order_revealed  surah_rukus  \
# 0   The Opening     Meccan                     5            1
# 1   The Opening     Meccan                     5            1
# 2   The Opening     Meccan                     5            1
# 3   The Opening     Meccan                     5            1
# 4   The Opening     Meccan                     5            1
#
#                          arabic_text_simple  ...  \
# 0   بِسْمِ اللَّهِ الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 1     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ  ...
# 2                  الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 3                   مَالِكِ يَوْمِ الدِّينِ  ...
# 4  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ  ...
#
#                             translation_ur_jalandhry  \
# 0  شروع الله کا نام لے کر جو بڑا مہربان نہایت رحم...
# 1  سب طرح کی تعریف خدا ہی کو (سزاوار) ہے جو تمام ...
# 2                          بڑا مہربان نہایت رحم والا
# 3                                انصاف کے دن کا حاکم
# 4  (اے پروردگار) ہم تیری ہی عبادت کرتے ہیں اور تج...
#
#                                translation_ur_jawadi  \
# 0           عظیم اور دائمی رحمتوں والے خدا کے نام سے
# 1  ساری تعریف اللہ کے لئے ہے جو عالمین کا پالنے و...
# 2                    وہ عظیم اوردائمی رحمتوں والا ہے
# 3                       روزِقیامت کا مالک و مختار ہے
# 4  پروردگار! ہم تیری ہی عبادت کرتے ہیں ا ور تجھی ...
#
#                             translation_ur_junagarhi  \
# 0  شروع کرتا ہوں اللہ تعالیٰ کے نام سے جو بڑا مہر...
# 1  سب تعریف اللہ تعالیٰ کے لئے ہے جو تمام جہانوں ...
# 2                      بڑا مہربان نہایت رحم کرنے واﻻ
# 3                 بدلے کے دن (یعنی قیامت) کا مالک ہے
# 4  ہم صرف تیری ہی عبادت کرتے ہیں اور صرف تجھ ہی س...
#
#                        translation_ur_kanzuliman  \
# 0    اللہ کے نام سے شروع جو بہت مہربان رحمت والا
# 1  سب خوبیاں اللہ کو جو مالک سارے جہان والوں کا،
# 2                          بہت مہربان رحمت والا،
# 3                               روز جزا کا مالک،
# 4        ہم تجھی کو پوجیں اور تجھی سے مدد چاہیں،
#
#                               translation_ur_maududi  \
# 0                  اللہ کے نام سے جو رحمان و رحیم ہے
# 1    تعریف اللہ ہی کے لیے ہے جو تمام کائنات کا رب ہے
# 2                                  رحمان اور رحیم ہے
# 3                                 روز جزا کا مالک ہے
# 4  ہم تیری ہی عبادت کرتے ہیں اور تجھی سے مدد مانگ...
#
#                                translation_ur_najafi  \
# 0  (شروع کرتا ہوں) اللہ کے نام سے جو بڑا مہربان ن...
# 1  ہر قسم کی تعریف اس اللہ کے لیے جو سب جہانوں کا...
# 2  جو (سب پر) بڑا مہربان (اور خاص بندوں پر) نہایت...
# 3              جزا و سزا کے دن کا مالک (و مختار) ہے۔
# 4  (اے اللہ!) ہم تیری ہی عبادت کرتے ہیں اور تجھ ہ...
#
#                                 translation_ur_qadri  \
# 0  اللہ کے نام سےشروع جو نہایت مہربان ہمیشہ رحم ف...
# 1  سب تعریفیں اللہ ہی کے لئے ہیں جو تمام جہانوں ک...
# 2                نہایت مہربان بہت رحم فرمانے والا ہے
# 3                                روزِ جزا کا مالک ہے
# 4  (اے اللہ!) ہم تیری ہی عبادت کرتے ہیں اور ہم تج...
#
#                                 translation_uz_sodik translation_zh_jian  \
# 0  Меҳрибон ва раҳмли Аллоҳнинг номи билан бошлай...          奉至仁至慈的真主之名
# 1  Барча мақтов, шукрлар оламларнинг тарбиячиси А...    一切赞颂全归真主，众世界 的主，
# 2  У Роҳман ва Раҳийм... (Барчага-кофирга ҳам, мў...             至仁至慈的主，
# 3  У қиёмат кунининг подшоҳи, эгаси. ("Дин" сўзи ...              报应日的主，
# 4  Фақат сенгагина ибодат қиламиз ва фақат сендан...        我们只崇拜你，只求你祐助
#
#   translation_zh_majian
# 0            奉至仁至慈的真主之名
# 1      一切贊頌，全歸真主，全世界的主，
# 2               至仁至慈的主，
# 3                報應日的主。
# 4         我們只崇拜你，只求你祐助，
#
# [5 rows x 128 columns]

# %%
# Get list of columns to drop - those starting with 'translation_' but not containing 'en_'
cols_to_drop = [col for col in df.columns if col.startswith(
    'translation_') and 'en_' not in col]

# Drop the identified columns
df = df.drop(columns=cols_to_drop)

# %%
df.head()
# Out:
#    surah  ayah surah_name  surah_total_ayas surah_name_transliteration  \
# 0      1     1    الفاتحة                 7                 Al-Faatiha
# 1      1     2    الفاتحة                 7                 Al-Faatiha
# 2      1     3    الفاتحة                 7                 Al-Faatiha
# 3      1     4    الفاتحة                 7                 Al-Faatiha
# 4      1     5    الفاتحة                 7                 Al-Faatiha
#
#   surah_name_en surah_type  surah_order_revealed  surah_rukus  \
# 0   The Opening     Meccan                     5            1
# 1   The Opening     Meccan                     5            1
# 2   The Opening     Meccan                     5            1
# 3   The Opening     Meccan                     5            1
# 4   The Opening     Meccan                     5            1
#
#                          arabic_text_simple  ...  \
# 0   بِسْمِ اللَّهِ الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 1     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ  ...
# 2                  الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 3                   مَالِكِ يَوْمِ الدِّينِ  ...
# 4  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ  ...
#
#                           translation_en_mubarakpuri  \
# 0  In the Name of Allah, the Most Gracious, the M...
# 1  Al-Hamd be to Allah, the Lord of all that exists.
# 2  Ar-Rahman (the Most Gracious), Ar-Rahim (the M...
# 3                The Owner of the Day of Recompense.
# 4           You we worship, and You we ask for help.
#
#                             translation_en_pickthall  \
# 0  In the name of Allah, the Beneficent, the Merc...
# 1            Praise be to Allah, Lord of the Worlds,
# 2                      The Beneficent, the Merciful.
# 3                     Master of the Day of Judgment,
# 4  Thee (alone) we worship; Thee (alone) we ask f...
#
#                                 translation_en_qarai  \
# 0  In the Name of Allah, the All-beneficent, the ...
# 1  All praise belongs to Allah, Lord of all the w...
# 2              the All-beneficent, the All-merciful,
# 3                  Master of the Day of Retribution.
# 4  You [alone] do we worship, and to You [alone] ...
#
#                            translation_en_qaribullah  \
# 0  In the Name of Allah, the Merciful, the Most M...
# 1            Praise be to Allah, Lord of the Worlds,
# 2                   the Merciful, the Most Merciful,
# 3                    Owner of the Day of Recompense.
# 4  You (alone) we worship; and You (alone) we rel...
#
#                                 translation_en_sahih  \
# 0  In the name of Allah, the Entirely Merciful, t...
# 1  [All] praise is [due] to Allah, Lord of the wo...
# 2    The Entirely Merciful, the Especially Merciful,
# 3                Sovereign of the Day of Recompense.
# 4      It is You we worship and You we ask for help.
#
#                                translation_en_sarwar  \
# 0  In the Name of Allah, the Beneficent, the Merc...
# 1   All praise belongs to God, Lord of the Universe,
# 2                       the Beneficent, the Merciful
# 3                  and Master of the Day of Judgment
# 4  (Lord), You alone We do worship and from You a...
#
#                                translation_en_shakir  \
# 0  In the name of Allah, the Beneficent, the Merc...
# 1  All praise is due to Allah, the Lord of the Wo...
# 2                      The Beneficent, the Merciful.
# 3                     Master of the Day of Judgment.
# 4  Thee do we serve and Thee do we beseech for help.
#
#                       translation_en_transliteration  \
# 0  Bismi All<u>a</U>hi a<b>l</B>rra<u>h</U>m<u>a<...
# 1  Al<u>h</U>amdu lill<u>a</U>hi rabbi alAA<u>a</...
# 2  A<b>l</B>rra<u>h</U>m<u>a</U>ni a<b>l</B>rra<u...
# 3         M<u>a</U>liki yawmi a<b>l</B>ddeen<b>i</b>
# 4  Iyy<u>a</U>ka naAAbudu waiyy<u>a</U>ka nastaAA...
#
#                            translation_en_wahiduddin  \
# 0  ﻿In the name of God, the Most Gracious, the Mo...
# 1  All praise is due to God, the Lord of the Univ...
# 2                      the Beneficent, the Merciful;
# 3                      Lord of the Day of Judgement.
# 4  You alone we worship, and to You alone we turn...
#
#                              translation_en_yusufali
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;
# 3                     Master of the Day of Judgment.
# 4         Thee do we worship, and Thine aid we seek.
#
# [5 rows x 30 columns]

# %%
df3 = pd.read_csv('quran.csv')
df['arabic_text_original'] = df3['ayah']

# %%
df.to_csv('full_quran.csv', index=False)
df.head(10)
# Out:
#    surah  ayah surah_name  surah_total_ayas surah_name_transliteration  \
# 0      1     1    الفاتحة                 7                 Al-Faatiha
# 1      1     2    الفاتحة                 7                 Al-Faatiha
# 2      1     3    الفاتحة                 7                 Al-Faatiha
# 3      1     4    الفاتحة                 7                 Al-Faatiha
# 4      1     5    الفاتحة                 7                 Al-Faatiha
# 5      1     6    الفاتحة                 7                 Al-Faatiha
# 6      1     7    الفاتحة                 7                 Al-Faatiha
# 7      2     1     البقرة               286                  Al-Baqara
# 8      2     2     البقرة               286                  Al-Baqara
# 9      2     3     البقرة               286                  Al-Baqara
#
#   surah_name_en surah_type  surah_order_revealed  surah_rukus  \
# 0   The Opening     Meccan                     5            1
# 1   The Opening     Meccan                     5            1
# 2   The Opening     Meccan                     5            1
# 3   The Opening     Meccan                     5            1
# 4   The Opening     Meccan                     5            1
# 5   The Opening     Meccan                     5            1
# 6   The Opening     Meccan                     5            1
# 7       The Cow    Medinan                    87           40
# 8       The Cow    Medinan                    87           40
# 9       The Cow    Medinan                    87           40
#
#                                   arabic_text_simple  ...  \
# 0            بِسْمِ اللَّهِ الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 1              الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ  ...
# 2                           الرَّحْمَـٰنِ الرَّحِيمِ  ...
# 3                            مَالِكِ يَوْمِ الدِّينِ  ...
# 4           إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ  ...
# 5                 اهْدِنَا الصِّرَاطَ الْمُسْتَقِيمَ  ...
# 6  صِرَاطَ الَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ...  ...
# 7        بِسْمِ اللَّهِ الرَّحْمَـٰنِ الرَّحِيمِ الم  ...
# 8  ذَٰلِكَ الْكِتَابُ لَا رَيْبَ ۛ فِيهِ ۛ هُدًى ...  ...
# 9  الَّذِينَ يُؤْمِنُونَ بِالْغَيْبِ وَيُقِيمُونَ...  ...
#
#                             translation_en_pickthall  \
# 0  In the name of Allah, the Beneficent, the Merc...
# 1            Praise be to Allah, Lord of the Worlds,
# 2                      The Beneficent, the Merciful.
# 3                     Master of the Day of Judgment,
# 4  Thee (alone) we worship; Thee (alone) we ask f...
# 5                         Show us the straight path,
# 6  The path of those whom Thou hast favoured; Not...
# 7                                    Alif. Lam. Mim.
# 8  This is the Scripture whereof there is no doub...
# 9  Who believe in the Unseen, and establish worsh...
#
#                                 translation_en_qarai  \
# 0  In the Name of Allah, the All-beneficent, the ...
# 1  All praise belongs to Allah, Lord of all the w...
# 2              the All-beneficent, the All-merciful,
# 3                  Master of the Day of Retribution.
# 4  You [alone] do we worship, and to You [alone] ...
# 5                     Guide us on the straight path,
# 6  the path of those whom You have blessed — such...
# 7                                    Alif, Lam, Mim.
# 8  This is the Book, there is no doubt in it, a g...
# 9  who believe in the Unseen, maintain the prayer...
#
#                            translation_en_qaribullah  \
# 0  In the Name of Allah, the Merciful, the Most M...
# 1            Praise be to Allah, Lord of the Worlds,
# 2                   the Merciful, the Most Merciful,
# 3                    Owner of the Day of Recompense.
# 4  You (alone) we worship; and You (alone) we rel...
# 5                     Guide us to the Straight Path,
# 6  the Path of those upon whom You have favored, ...
# 7                                      AlifLaamMeem.
# 8  That is the (Holy) Book, where there is no dou...
# 9  Who believe in the unseen and establish the (d...
#
#                                 translation_en_sahih  \
# 0  In the name of Allah, the Entirely Merciful, t...
# 1  [All] praise is [due] to Allah, Lord of the wo...
# 2    The Entirely Merciful, the Especially Merciful,
# 3                Sovereign of the Day of Recompense.
# 4      It is You we worship and You we ask for help.
# 5                    Guide us to the straight path -
# 6  The path of those upon whom You have bestowed ...
# 7                                   Alif, Lam, Meem.
# 8  This is the Book about which there is no doubt...
# 9  Who believe in the unseen, establish prayer, a...
#
#                                translation_en_sarwar  \
# 0  In the Name of Allah, the Beneficent, the Merc...
# 1   All praise belongs to God, Lord of the Universe,
# 2                       the Beneficent, the Merciful
# 3                  and Master of the Day of Judgment
# 4  (Lord), You alone We do worship and from You a...
# 5                (Lord), guide us to the right path,
# 6  the path of those to whom You have granted ble...
# 7                                    Alif. Lam. Mim.
# 8  There is no doubt that this book is a guide fo...
# 9  the pious who believe in the unseen, attend to...
#
#                                translation_en_shakir  \
# 0  In the name of Allah, the Beneficent, the Merc...
# 1  All praise is due to Allah, the Lord of the Wo...
# 2                      The Beneficent, the Merciful.
# 3                     Master of the Day of Judgment.
# 4  Thee do we serve and Thee do we beseech for help.
# 5                         Keep us on the right path.
# 6  The path of those upon whom Thou hast bestowed...
# 7                                      Alif Lam Mim.
# 8  This Book, there is no doubt in it, is a guide...
# 9  Those who believe in the unseen and keep up pr...
#
#                       translation_en_transliteration  \
# 0  Bismi All<u>a</U>hi a<b>l</B>rra<u>h</U>m<u>a<...
# 1  Al<u>h</U>amdu lill<u>a</U>hi rabbi alAA<u>a</...
# 2  A<b>l</B>rra<u>h</U>m<u>a</U>ni a<b>l</B>rra<u...
# 3         M<u>a</U>liki yawmi a<b>l</B>ddeen<b>i</b>
# 4  Iyy<u>a</U>ka naAAbudu waiyy<u>a</U>ka nastaAA...
# 5  Ihdin<u>a</U> a<b>l</B><u>ss</U>ir<u>at</U>a a...
# 6  <u>S</U>ir<u>at</U>a alla<u>th</U>eena anAAamt...
# 7                                 Alifl<u>a</u>mmeem
# 8  <u>Tha</u>lika alkit<u>a</u>bu l<u>a</u> rayba...
# 9  Alla<u>th</u>eena yuminoona bi<b>a</b>lghaybi ...
#
#                            translation_en_wahiduddin  \
# 0  ﻿In the name of God, the Most Gracious, the Mo...
# 1  All praise is due to God, the Lord of the Univ...
# 2                      the Beneficent, the Merciful;
# 3                      Lord of the Day of Judgement.
# 4  You alone we worship, and to You alone we turn...
# 5                     Guide us to the straight path:
# 6  the path of those You have blessed; not of tho...
# 7                                      Alif Lam Mim.
# 8  This is the Book; there is no doubt in it. It ...
# 9  who believe in the unseen, and are steadfast i...
#
#                              translation_en_yusufali  \
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;
# 3                     Master of the Day of Judgment.
# 4         Thee do we worship, and Thine aid we seek.
# 5                          Show us the straight way,
# 6  The way of those on whom Thou hast bestowed Th...
# 7                                           A. L. M.
# 8  This is the Book; in it is guidance sure, with...
# 9  Who believe in the Unseen, are steadfast in pr...
#
#                                 arabic_text_original
# 0             بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1              ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2                            ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3                            مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4           إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# 5                 ٱهْدِنَا ٱلصِّرَٰطَ ٱلْمُسْتَقِيمَ
# 6  صِرَٰطَ ٱلَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ...
# 7                                              الٓمٓ
# 8  ذَٰلِكَ ٱلْكِتَٰبُ لَا رَيْبَ ۛ فِيهِ ۛ هُدًۭى...
# 9  ٱلَّذِينَ يُؤْمِنُونَ بِٱلْغَيْبِ وَيُقِيمُونَ...
#
# [10 rows x 31 columns]

# %%
# Database connection details
db_host = os.getenv("SUPABASE_POSTGRES_HOST")
db_name = os.getenv("SUPABASE_POSTGRES_DATABASE")
db_user = os.getenv("SUPABASE_POSTGRES_USER")
db_password = os.getenv("SUPABASE_POSTGRES_PASSWORD")

# %%
# Create database connection
conn, cur = create_db_connection(db_host, db_name, db_user, db_password)

try:
    # Begin transaction
    conn.autocommit = True

    # Insert data into normalized tables
    print("Inserting surahs...")
    surah_mapping = insert_surahs(cur, df)

    print("Inserting languages and translators...")
    translator_mapping = insert_languages_and_translators(cur, df)

    print("Inserting ayahs...")
    ayah_mapping = insert_ayahs(cur, df, surah_mapping)

    print("Inserting translations...")
    insert_translations(cur, df, ayah_mapping, translator_mapping)

    # Commit the transaction
    conn.commit()
    print("Data successfully inserted into the normalized database!")

except Exception as e:
    conn.rollback()
    print(f"An error occurred: {str(e)}")
    raise

finally:
    cur.close()
    conn.close()
# Out:
# Inserting surahs...
# Inserting languages and translators...
# Processed 1 valid languages
# Processed 16 translators
# Inserting ayahs...
# Inserting translations...
# Data successfully inserted into the normalized database!
